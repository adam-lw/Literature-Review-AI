# %%
from papery.core.db import load_table

df = load_table("test.test_specter_db_2")

# %%
display(df)
# Out:
#                                        paperId  \
# 0     438ea4f6becaadca82c9f9904208a423a0cfeba0
# 1     10c64e5aaff9f70dffc8c29a577376d085e9340b
# 2     9543d4b9c6f71bdececdad7f397ad68cac359d2d
# 3     80bb9c78b9c30f035adbda2eeb86d88ec32eb422
# 4     46a627d9535277a067b54005c98bd8ffe06bc7c6
# ...                                        ...
# 1495  676f8e91ab51db48f7a136600e6bb19adbc0bb54
# 1496  3eedfc92689a99f468c562e41e8b7ee6e19e673d
# 1497  335ca0fba8342d05c1ce0c5d4502fad6fbf77216
# 1498  6118910c4014cc6c061198a2d88c080ab56ea452
# 1499  9d43f52334b6303f31bac07ea633e93332cba5a8
#
#                                              specter_v2
# 0     [0.31425676,0.33489272,-0.6887951,0.512959,0.1...
# 1     [0.43484354,0.837359,-0.5026119,0.19020805,0.2...
# 2     [0.030891502,0.6406657,-0.6195086,0.34981707,-...
# 3     [0.5388222,0.5259829,-0.77866876,0.22378188,-0...
# 4     [0.5261739,0.46893704,-0.3824243,0.6138343,0.0...
# ...                                                 ...
# ...
