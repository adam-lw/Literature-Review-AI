# %%
from papery.core.api.semantic_scholar import collect_specter_embeddings


out = await collect_specter_embeddings(
    table_uri="test.test_papers", id_col="paperId", embedding="specter_v2"
)
# Out:
# Initialised dispatcher semantic_scholar_api
# /Users/adam/Documents/Projects/Literature-Review-AI/src/papery/core/api/semantic_scholar.py:171: RuntimeWarning: coroutine 'api_call' was never awaited
#   *([
# ...
# 2026-03-08 16:29:47.569 | INFO     | papery.core.api.core:api_call:34 - Making API call to semantic_scholar_api with endpoint graph/v1/paper/batch and header {'fields': 'paperId,embedding.specter_v2'}
# ...

# %%
out
# Out:
#                                       paperId  \
# 0    000417ac406bb7b38aa1cbdb7ebd10406f02bb99
# 1    000d02535797fd8ca7b0f04edcbf356e089a5338
# 2    001339b4ab31c1cb655651cf3a4b244ac2d8654c
# 3    007d521a11a5cb965cf4e3a25978b6089e042d89
# 4    00b3019aa6101958840d720f9b6d1eba10e8bd36
# ..                                        ...
# 491  4df9580058ac997b1457ffb9444c578ce1730fdd
# 492  4e2f4d2f4f478e35106bede21022c27430268d50
# 493  4e8371a316bdeb74a62fff0852cb9fd1a3a1208c
# 494  4f2db2a33e4684c50c3cebd1733246382fda6642
# 495  12d6706a3539a5c7d3d310785548debc6b6124e1
#
#                                             specter_v2
# 0    [-0.011586458422243595, 0.3329941928386688, -0...
# 1    [0.47697994112968445, 0.6898596882820129, -0.1...
# 2    [0.6039397716522217, 0.7822109460830688, -0.75...
# 3    [0.4227554500102997, 0.07681553065776825, 0.16...
# 4    [0.3544972240924835, 0.7069027423858643, 0.004...
# ..                                                 ...
# ...
